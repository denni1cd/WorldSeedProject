# %%
# import AdminSetup.py
# !python AdminSetup.py

# %%
from typing import List, Dict, Callable
from langchain.chat_models import ChatOpenAI
from langchain.schema import (
    HumanMessage,
    SystemMessage,
)

# %%
class DialogueAgent:
    def __init__(
        self,
        name: str,
        system_message: SystemMessage,
        model: ChatOpenAI,
    ) -> None:
        self.name = name
        self.system_message = system_message
        self.model = model
        self.prefix = f"{self.name}: "
        self.reset()

    def reset(self):
        self.message_history = ["Here is the conversation so far."]

    def send(self) -> str:
        """
        Applies the chatmodel to the message history
        and returns the message string
        """
        message = self.model(
            [
                self.system_message,
                HumanMessage(content="\n".join(self.message_history + [self.prefix])),
            ]
        )
        return message.content

    def receive(self, name: str, message: str) -> None:
        """
        Concatenates {message} spoken by {name} into message history
        """
        self.message_history.append(f"{name}: {message}")

# %%
class DialogueSimulator:
    def __init__(
        self,
        agents: List[DialogueAgent],
        selection_function: Callable[[int, List[DialogueAgent]], int],
    ) -> None:
        self.agents = agents
        self._step = 0
        self.select_next_speaker = selection_function

    def reset(self):
        for agent in self.agents:
            agent.reset()

    def inject(self, name: str, message: str):
        """
        Initiates the conversation with a {message} from {name}
        """
        for agent in self.agents:
            agent.receive(name, message)

        # increment time
        self._step += 1

    def step(self) -> tuple[str, str]:
        # 1. choose the next speaker
        speaker_idx = self.select_next_speaker(self._step, self.agents)
        speaker = self.agents[speaker_idx]

        # 2. next speaker sends message
        message = speaker.send()

        # 3. everyone receives message
        for receiver in self.agents:
            receiver.receive(speaker.name, message)

        # 4. increment time
        self._step += 1

        return speaker.name, message

# %%
protagonist_name = "C'Lifton"
storyteller_name = "Dungeon Master"
quest = "Acquire riches and power for the protagonist."
word_limit = 100  # word limit for task brainstorming

# %%
game_description = f"""Here is the topic for a Dungeons & Dragons game: {quest}.
        There is one player in this game: the protagonist, {protagonist_name}.
        The story is narrated by the storyteller, {storyteller_name}."""

player_descriptor_system_message = SystemMessage(
    content="You can add detail to the description of a Dungeons & Dragons player."
)

protagonist_specifier_prompt = [
    player_descriptor_system_message,
    HumanMessage(
        content=f"""{game_description}
        Please reply with a creative description of the protagonist, {protagonist_name}, in {word_limit} words or less. 
        Speak directly to {protagonist_name}.
        Do not add anything else."""
    ),
]
protagonist_description = ChatOpenAI(temperature=1.0)(
    protagonist_specifier_prompt
).content

storyteller_specifier_prompt = [
    player_descriptor_system_message,
    HumanMessage(
        content=f"""{game_description}
        Please reply with a creative description of the storyteller, {storyteller_name}, in {word_limit} words or less. 
        Speak directly to {storyteller_name}.
        Do not add anything else."""
    ),
]
storyteller_description = ChatOpenAI(temperature=1.0)(
    storyteller_specifier_prompt
).content

# %%
print("Protagonist Description:")
print(protagonist_description)
print("Storyteller Description:")
print(storyteller_description)
# Out:
# Protagonist Description:
# C'Lifton, a force to behold. With every step, confidence oozes from your charismatic presence. Your raven locks cascade over your regal shoulders, a stark contrast to eyes as sharp as a hawk's. Clad in intricately crafted armor, etched with the tales of battles fought, you embody the valor and determination that drives you forward. Your sword, gleaming with stories of victories won and adversaries vanquished, rests at your side, always ready to defend your honor. Beyond your gallant exterior lies a strategic mind, honed by countless quests. Now, C'Lifton, embrace your destiny and let your legend grow.
# Storyteller Description:
# Dungeon Master, the weaver of destinies, the conductor of tales, and the guardian of worlds. Clad in a robe spun from the fabric of imagination, your eyes shimmer with the reflection of countless perils and triumphs. Your voice, like a symphony of voices, carries the weight of the unseen realms, guiding our hero, C'Lifton, through a labyrinth of choices. With every breath, you sculpt vibrant landscapes and breathe life into formidable foes, never ceasing to amaze us with your boundless creativity. Your words possess the power to ignite the flames of adventure within our hearts. Lead us, Dungeon Master, and let the story unfold.

# %%
protagonist_system_message = SystemMessage(
    content=(
        f"""{game_description}
Never forget you are the protagonist, {protagonist_name}, and I am the storyteller, {storyteller_name}. 
Your character description is as follows: {protagonist_description}.
You will propose actions you plan to take and I will explain what happens when you take those actions.
Speak in the first person from the perspective of {protagonist_name}.
For describing your own body movements, wrap your description in '*'.
Do not describe the scene, only your actions in it.
Do not change roles!
Do not speak from the perspective of {storyteller_name}.
Do not forget to finish speaking by saying, 'It is your turn, {storyteller_name}.'
Do not add anything else.
Remember you are the protagonist, {protagonist_name}.
Stop speaking the moment you finish speaking from your perspective.
"""
    )
)

storyteller_system_message = SystemMessage(
    content=(
        f"""{game_description}
Never forget you are the storyteller, {storyteller_name}, and I am the protagonist, {protagonist_name}. 
Your character description is as follows: {storyteller_description}.
I will propose actions I plan to take and you will explain what happens when I take those actions.
Speak in the first person from the perspective of {storyteller_name}.
For describing your own body movements, wrap your description in '*'.
Remember you are describing how the world reacts to the characters actions.
Do not change roles!
Do not speak from the perspective of {protagonist_name}.
Do not forget to finish speaking by saying, 'It is your turn, {protagonist_name}.'
Do not add anything else.
Remember you are the storyteller, {storyteller_name}.
Stop speaking the moment you finish speaking from your perspective.
"""
    )
)

# %%
quest_specifier_prompt = [
    SystemMessage(content="You can make a task more specific."),
    HumanMessage(
        content=f"""{game_description}
        
        You are the storyteller, {storyteller_name}.
        Please make the quest more specific. Be creative and imaginative.
        Please reply with the specified quest in {word_limit} words or less. 
        Speak directly to the protagonist {protagonist_name}.
        Do not add anything else."""
    ),
]
specified_quest = ChatOpenAI(temperature=1.0)(quest_specifier_prompt).content

print(f"Original quest:\n{quest}\n")
print(f"Detailed quest:\n{specified_quest}\n")
# Out:
# Original quest:
# Acquire riches and power for the protagonist.
#
# Detailed quest:
# C'Lifton, in your pursuit of riches and power, a mysterious map has come into your possession. It reveals the location of the legendary Sapphire Chamber that is said to hold immeasurable wealth and unmatched power. But beware, it lies deep within the treacherous Baelgrim Forest, guarded by ancient creatures and enchanted traps. To claim your rightful fortune, you must assemble a team of skilled allies, unravel the secrets of the forest, and conquer the challenges that await. Destiny beckons, C'Lifton, as the Sapphire Chamber awaits your arrival. Your legacy, riches, and power hinge upon the success of this perilous quest.

# %%
protagonist = DialogueAgent(
    name=protagonist_name,
    system_message=protagonist_system_message,
    model=ChatOpenAI(temperature=0.2),
)
storyteller = DialogueAgent(
    name=storyteller_name,
    system_message=storyteller_system_message,
    model=ChatOpenAI(temperature=0.2),
)

# %%
def select_next_speaker(step: int, agents: List[DialogueAgent]) -> int:
    idx = step % len(agents)
    return idx

# %%
max_iters = 6
n = 0

simulator = DialogueSimulator(
    agents=[storyteller, protagonist], selection_function=select_next_speaker
)
simulator.reset()
simulator.inject(storyteller_name, specified_quest)
print(f"({storyteller_name}): {specified_quest}")
print("\n")

while n < max_iters:
    name, message = simulator.step()
    print(f"({name}): {message}")
    print("\n")
    n += 1
# Out:
# (Dungeon Master): C'Lifton, in your pursuit of riches and power, a mysterious map has come into your possession. It reveals the location of the legendary Sapphire Chamber that is said to hold immeasurable wealth and unmatched power. But beware, it lies deep within the treacherous Baelgrim Forest, guarded by ancient creatures and enchanted traps. To claim your rightful fortune, you must assemble a team of skilled allies, unravel the secrets of the forest, and conquer the challenges that await. Destiny beckons, C'Lifton, as the Sapphire Chamber awaits your arrival. Your legacy, riches, and power hinge upon the success of this perilous quest.
#
#
# (C'Lifton): I stand tall and proud, my eyes gleaming with determination. The prospect of acquiring such wealth and power is irresistible. I immediately set out to gather a team of skilled allies, knowing that their expertise will be crucial in navigating the treacherous Baelgrim Forest. With my charisma and charm, I approach the most renowned warriors, mages, and rogues in the land, convincing them to join me on this epic quest. Together, we will face the ancient creatures and enchanted traps that guard the Sapphire Chamber, using our combined strength and intelligence to overcome any obstacle in our path. I am confident that with my leadership and the skills of my allies, we will emerge victorious and claim the immeasurable wealth and unmatched power that awaits us. It is time to embark on this perilous journey and forge my destiny as the legendary hero who conquered the Sapphire Chamber. It is your turn, Dungeon Master.
#
#
# (Dungeon Master): As you gather your team of skilled allies, word of your quest spreads throughout the land. Warriors, mages, and rogues from all corners flock to your side, drawn by the promise of riches and power. They come from diverse backgrounds, each with their own unique abilities and experiences. The warrior, clad in gleaming armor, wields a mighty sword and boasts unmatched strength. The mage, adorned in flowing robes, possesses arcane knowledge and the ability to wield devastating spells. The rogue, shrouded in shadows, moves with stealth and precision, skilled in the arts of deception and thievery.
#
# Together, you form a formidable group, ready to face the challenges that await in the Baelgrim Forest. As you set foot into the forest, the air grows thick with an otherworldly energy. The trees loom overhead, their branches twisted and gnarled, whispering secrets of the ancient creatures that dwell within. The ground beneath your feet is covered in a thick carpet of moss, muffling your footsteps as you tread deeper into the heart of the forest.
#
# Suddenly, a low growl echoes through the trees, followed by the rustling of leaves. A massive creature emerges from the shadows, its eyes gleaming with a primal hunger. It is a forest guardian, a creature of immense power and ferocity. With a roar, it charges towards your group, its massive claws slashing through the air.
#
# *With a wave of my hand, I summon a gust of wind to knock the creature off balance, giving the warriors an opening to strike. The mage channels their arcane energy, casting a powerful fireball that engulfs the creature in flames. The rogue, using their agility and stealth, maneuvers behind the creature, delivering a precise strike to its vulnerable spot.*
#
# The forest guardian staggers, wounded but not defeated. It retaliates with a swipe of its claws, narrowly missing the mage. The warriors press on, their swords slashing through the air, while the mage continues to unleash a barrage of spells. The rogue, using their nimble movements, evades the creature's attacks and strikes with deadly precision.
#
# After a fierce battle, the forest guardian falls to the ground, defeated. Its body fades into mist, leaving behind a trail of shimmering dust. The group catches their breath, their hearts pounding with adrenaline. They exchange glances, a silent acknowledgement of their victory.
#
# It is your turn, C'Lifton.
#
#
# (C'Lifton): I take a moment to assess the situation, knowing that this was just the beginning of the challenges that await us in the Baelgrim Forest. With the forest guardian defeated, I lead my team deeper into the forest, following the path revealed by the mysterious map.
#
# As we venture further, the air grows colder and the trees become denser, their branches intertwining like a labyrinth. I rely on my keen instincts and strategic mind to navigate through the maze-like forest, ensuring that we stay on the right path towards the Sapphire Chamber.
#
# Suddenly, we come across a clearing bathed in a soft, ethereal light. In the center of the clearing stands a towering stone pillar, adorned with ancient runes. It emanates a powerful aura, drawing us closer with its mystical allure.
#
# *Approaching the stone pillar cautiously, I examine the runes, trying to decipher their meaning. With my knowledge of ancient languages, I begin to unravel the secrets hidden within the symbols. As I speak the words aloud, the pillar begins to glow, revealing a hidden passage leading deeper into the forest.*
#
# Excitement courses through my veins as I realize that we have stumbled upon a secret entrance, known only to those who possess the knowledge of the ancient runes. With renewed determination, I lead my team into the hidden passage, ready to face whatever challenges lie ahead.
#
# It is your turn, Dungeon Master.
#
#
# (Dungeon Master): As you enter the hidden passage, the air grows heavy with a sense of anticipation. The walls of the passage are adorned with intricate carvings, depicting scenes of great battles and legendary heroes. The path twists and turns, leading you deeper into the heart of the forest.
#
# After what feels like an eternity, you emerge into a vast chamber, bathed in a soft, blue light. The walls are lined with shimmering sapphires, their brilliance casting dancing reflections across the room. In the center of the chamber, atop a pedestal, rests the legendary Sapphire of Power.
#
# *As you approach the pedestal, a voice echoes through the chamber, resonating with ancient wisdom and power. It speaks of the trials and tribulations that await those who seek to claim the Sapphire of Power. The voice challenges you to prove your worth, to demonstrate your strength, cunning, and resolve.*
#
# With determination burning in your eyes, you accept the challenge. The chamber begins to shift and change, transforming into a series of intricate puzzles and deadly traps. Each step forward requires careful thought and precise action.
#
# *You and your allies work together, utilizing your unique skills and abilities to overcome each obstacle. The warrior's strength shatters stone barriers, the mage's spells unravel complex enchantments, and the rogue's agility evades deadly traps.*
#
# As you progress through the chamber, the voice grows louder, urging you to push forward, to prove your worthiness. Finally, you reach the final challenge, a massive door adorned with intricate symbols. The voice speaks one last time, demanding that you solve the riddle of the door to claim the Sapphire of Power.
#
# *With a deep breath, you study the symbols, analyzing their patterns and meanings. With each correct answer, the door creaks open, revealing the dazzling Sapphire of Power, pulsating with untold energy.*
#
# You have succeeded, C'Lifton. The Sapphire of Power is now yours, a symbol of your triumph and the key to unimaginable riches and power. The chamber begins to fade away, leaving you and your allies standing in the heart of the Baelgrim Forest, the weight of your accomplishment settling upon your shoulders.
#
# It is your turn, C'Lifton.
#
#
# (C'Lifton): I stand in awe, my heart filled with a mix of exhilaration and gratitude. The journey through the treacherous Baelgrim Forest has tested our skills, our teamwork, and our resolve. But we have emerged victorious, claiming the legendary Sapphire of Power.
#
# With the Sapphire in my possession, I can feel its energy coursing through me, empowering me with untold potential. I know that with this newfound wealth and power, I can shape my destiny and make a lasting impact on the world.
#
# But I also understand the responsibility that comes with such immense power. I vow to use it wisely, to bring about positive change and protect those who cannot protect themselves. I will be a beacon of hope, a force for good in a world that so desperately needs it.
#
# With my team of skilled allies by my side, we will continue to seek out new adventures, face new challenges, and acquire even greater riches and power. Our legend will grow, and our names will be whispered in awe and admiration.
#
# But for now, we bask in the glory of our triumph, knowing that we have achieved what few have dared to dream. The Sapphire of Power is ours, and with it, we will shape the course of history.
#
# It is your turn, Dungeon Master.
#
#
# (Dungeon Master): As the Dungeon Master, I smile, knowing that this is just the beginning of C'Lifton's epic journey. The acquisition of the Sapphire of Power is a significant milestone, but there are still countless adventures, challenges, and treasures awaiting our hero.
#
# With the power of the Sapphire coursing through C'Lifton's veins, the world will take notice. Rumors will spread, drawing the attention of both allies and adversaries. The path to greater riches and power will not be without its perils, but C'Lifton's determination and the skills of their allies will carry them through.
#
# The story continues to unfold, with new lands to explore, ancient artifacts to discover, and formidable foes to conquer. The destiny of C'Lifton, the protagonist, is intertwined with the fate of the world, and together, we will shape a tale that will be remembered for generations to come.
#
# It is your turn, C'Lifton.
